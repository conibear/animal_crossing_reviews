# %% [markdown]
# # I am an Aminal Crossing Lover!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Animal Crossing New Horizon (ACNH) is a life simulation video game developed by Nintendo. It was initially announced on September 13 2018, and ACNH fans around the globe went viral and start discussing about the game. Interestingly ACNH became the best-selling game in the Animal Crossing series, partially because it was officially released during the COVID-19 pandemic on March 20, 20202, and it immediately became a worldwide stay-at-home game.
#
# I have been playing Animal Crossing series since the release of the 3DS version - New Leaf, and fell in love with it. Coincidently I have been doing Machine Learning during the pandemic, here I decided to utilize my skills and use **Sentimenal Analysis** to analyze the reviews from players or comments from game rating websites, in order to understand if the majority reviews are leaning on postiive or negative.
#
# ### Stay Tuned!

# %% [markdown]
# # Import libraries and data files

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data files
critics = pd.read_csv('data/critic.csv')
items = pd.read_csv('data/items.csv')
reviews = pd.read_csv('data/user_reviews.csv')
villagers = pd.read_csv('data/villagers.csv')

# %%
critics.head()
# Out:
#    grade       publication                                               text  \
# 0    100   Pocket Gamer UK  Animal Crossing; New Horizons, much like its p...
# 1    100            Forbes  Know that if you’re overwhelmed with the world...
# 2    100         Telegraph  With a game this broad and lengthy, there’s mo...
# 3    100             VG247  Animal Crossing: New Horizons is everything I ...
# 4    100  Nintendo Insider  Above all else, Animal Crossing: New Horizons ...
#
#          date
# 0  2020-03-16
# 1  2020-03-16
# 2  2020-03-16
# 3  2020-03-16
# 4  2020-03-16

# %%
items.head()

# %%
reviews.head()
# Out:
#    grade     user_name                                               text  \
# 0      4      mds27272  My gf started playing before me. No option to ...
# 1      5      lolo2178  While the game itself is great, really relaxin...
# 2      0      Roachant  My wife and I were looking forward to playing ...
# 3      0        Houndf  We need equal values and opportunities for all...
# 4      0  ProfessorFox  BEWARE!  If you have multiple people in your h...
#
#          date
# 0  2020-03-20
# 1  2020-03-20
# 2  2020-03-20
# 3  2020-03-20
# 4  2020-03-20

# %%
villagers.head()

# %% [markdown]
# # Data exploration

# %%
# dataframe description
critics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   grade        107 non-null    int64
#  1   publication  107 non-null    object
#  2   text         107 non-null    object
#  3   date         107 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.5+ KB

# %%
# dataframe check empty data
critics.isna().sum()
# Out:
# grade          0
# publication    0
# text           0
# date           0
# dtype: int64

# %%
# change date from object to datetime
critics['date'] = pd.to_datetime(critics['date'])
critics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   grade        107 non-null    int64
#  1   publication  107 non-null    object
#  2   text         107 non-null    object
#  3   date         107 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 3.5+ KB

# %%
# dataframe description
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   grade      2999 non-null   int64
#  1   user_name  2999 non-null   object
#  2   text       2999 non-null   object
#  3   date       2999 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 93.8+ KB

# %%
# dataframe check empty data
reviews.isna().sum()
# Out:
# grade        0
# user_name    0
# text         0
# date         0
# dtype: int64

# %%
# change date from object to datetime
reviews['date'] = pd.to_datetime(reviews['date'])
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   grade      2999 non-null   int64
#  1   user_name  2999 non-null   object
#  2   text       2999 non-null   object
#  3   date       2999 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 93.8+ KB
